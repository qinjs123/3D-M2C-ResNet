# %%
import torchvision
import torch
import gc
import warnings
import time
import numpy as np
from PIL import Image
import scipy.io as sio
import os
import pandas as pd
import seaborn as sns
import spectral

# Visualization
import matplotlib.pyplot as plt
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
from matplotlib.pyplot import cm
init_notebook_mode(connected=True)
# %matplotlib inline

# Machine learning
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, cohen_kappa_score
from sklearn.decomposition import IncrementalPCA

# Deep learning
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import (Input, Conv3D, BatchNormalization, Activation, Add, 
                                     MaxPooling3D, GlobalAveragePooling3D, GlobalMaxPooling3D,
                                     Flatten, Dense, Dropout, Concatenate, UpSampling3D,
                                     Reshape, Multiply, Permute, Lambda)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import to_categorical
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>

# %%
## Data Preprocessing Functions
def SplitTr_Te(HSI, GT, TeRatio, randomState=345):
    """Split data into training and testing sets"""
    Tr, Te, TrC, TeC = train_test_split(HSI, GT, test_size=TeRatio, random_state=randomState, stratify=GT)
    return Tr, Te, TrC, TeC

def DL_Method(HSI, numComponents = 75):
    """Dimensionality reduction using Incremental PCA"""
    RHSI = np.reshape(HSI, (-1, HSI.shape[2]))
    n_batches = 256
    inc_pca = IncrementalPCA(n_components=numComponents)
    for X_batch in np.array_split(RHSI, n_batches):
        inc_pca.partial_fit(X_batch)
    X_ipca = inc_pca.transform(RHSI)
    RHSI = np.reshape(X_ipca, (HSI.shape[0],HSI.shape[1], numComponents))
    return RHSI

def ZeroPad(HSI, margin=2):
    """Add zero padding to HSI data"""
    NHSI = np.zeros((HSI.shape[0] + 2 * margin, HSI.shape[1] + 2* margin, HSI.shape[2]))
    x_offset = margin
    y_offset = margin
    NHSI[x_offset:HSI.shape[0] + x_offset, y_offset:HSI.shape[1] + y_offset, :] = HSI
    return NHSI

def HSICubes(HSI, GT, WinSize=5, removeZeroLabels = True):
    """Extract spatial-spectral cubes from HSI data"""
    margin = int((WinSize - 1) / 2)
    zeroPaddedX = ZeroPad(HSI, margin=margin)
    # Split patches
    patchesData = np.zeros((HSI.shape[0] * HSI.shape[1], WinSize, WinSize, HSI.shape[2]))
    patchesLabels = np.zeros((HSI.shape[0] * HSI.shape[1]))
    patchIndex = 0
    for r in range(margin, zeroPaddedX.shape[0] - margin):
        for c in range(margin, zeroPaddedX.shape[1] - margin):
            patch = zeroPaddedX[r - margin:r + margin + 1, c - margin:c + margin + 1]   
            patchesData[patchIndex, :, :, :] = patch
            patchesLabels[patchIndex] = GT[r-margin, c-margin]
            patchIndex = patchIndex + 1
    if removeZeroLabels:
        patchesData = patchesData[patchesLabels>0,:,:,:]
        patchesLabels = patchesLabels[patchesLabels>0]
        patchesLabels -= 1
    return patchesData, patchesLabels

# %%
## Data Augmentation and Balancing
def augment_3d_hsi(sample, prob=0.5):
    """Augment 3D hyperspectral data"""
    augmented = sample.copy()
    
    # Random spatial flips
    if np.random.random() < prob:
        augmented = np.flip(augmented, axis=0)  # Vertical flip
    if np.random.random() < prob:
        augmented = np.flip(augmented, axis=1)  # Horizontal flip
    
    # Random rotation (multiples of 90 degrees)
    if np.random.random() < prob:
        rot_k = np.random.randint(1, 4)
        augmented = np.rot90(augmented, k=rot_k, axes=(0, 1))
    
    # Spectral noise injection
    if np.random.random() < prob:
        noise = np.random.normal(0, 0.01, size=augmented.shape)
        augmented = augmented + noise
        augmented = np.clip(augmented, 0, 1)
    
    # Spectral band shifting
    if np.random.random() < prob:
        shift = np.random.randint(-2, 3)
        augmented = np.roll(augmented, shift, axis=2)
    
    return augmented

def balance_dataset(X, y_onehot, target=1000):
    """Balance dataset by augmenting minority classes and downsampling majority classes"""
    y_labels = np.argmax(y_onehot, axis=1)
    X_balanced = []
    y_balanced = []
    
    # Calculate class distribution
    class_counts = np.bincount(y_labels)
    num_classes = len(class_counts)
    
    print(f"Original class distribution: {class_counts}")
    
    for cls in range(num_classes):
        # Extract samples of current class
        cls_mask = (y_labels == cls)
        X_cls = X[cls_mask]
        y_cls = y_onehot[cls_mask]
        current_count = len(X_cls)
        
        # Handle class balancing
        if current_count < target:
            # Need to upsample (augment)
            need = target - current_count
            print(f"Augmenting class {cls}: from {current_count} to {target}")
            
            # Generate augmented samples
            augmented_samples = []
            idx = 0
            while len(augmented_samples) < need:
                sample = X_cls[idx % current_count]
                augmented = augment_3d_hsi(sample)
                augmented_samples.append(augmented)
                idx += 1
            
            # Combine original and augmented samples
            X_balanced.extend(X_cls)
            X_balanced.extend(augmented_samples)
            y_balanced.extend(y_cls)
            y_balanced.extend([y_cls[i % current_count] for i in range(need)])
        else:
            # Downsample majority classes
            if current_count > target:
                indices = np.random.choice(current_count, target, replace=False)
                X_balanced.extend(X_cls[indices])
                y_balanced.extend(y_cls[indices])
                print(f"Downsampling class {cls}: from {current_count} to {target}")
            else:  # Exactly target count
                X_balanced.extend(X_cls)
                y_balanced.extend(y_cls)
                print(f"Class {cls}: keeping {current_count} samples")
    
    # Convert to numpy arrays
    X_balanced_np = np.array(X_balanced)
    y_balanced_np = np.array(y_balanced)
    
    # Verify sample count match
    assert len(X_balanced_np) == len(y_balanced_np), \
        f"Sample count mismatch: features {len(X_balanced_np)}, labels {len(y_balanced_np)}"
    
    # Print balanced distribution
    balanced_labels = np.argmax(y_balanced_np, axis=1)
    balanced_counts = np.bincount(balanced_labels, minlength=num_classes)
    print(f"Balanced class distribution: {balanced_counts}")
    
    return X_balanced_np, y_balanced_np

# %%
## Model Components
def channel_attention(input_feature, ratio=8):
    """Channel attention module"""
    channel_axis = 1 if K.image_data_format() == "channels_first" else -1
    channel = input_feature.shape[channel_axis]
    
    # Shared dense layers
    def shared_dense(x):
        x = Dense(channel // ratio, activation='relu', 
                  kernel_initializer='he_normal', use_bias=True)(x)
        return Dense(channel, kernel_initializer='he_normal', use_bias=True)(x)
    
    # Global average and max pooling
    avg_pool = GlobalAveragePooling3D()(input_feature)
    avg_pool = Reshape((1, 1, channel))(avg_pool)
    avg_pool = shared_dense(avg_pool)
    
    max_pool = GlobalMaxPooling3D()(input_feature)
    max_pool = Reshape((1, 1, channel))(max_pool)
    max_pool = shared_dense(max_pool)
    
    # Attention weighting
    attention = Add()([avg_pool, max_pool])
    attention = Activation('sigmoid')(attention)
    
    if K.image_data_format() == "channels_first":
        attention = Permute((3, 1, 2))(attention)
    
    return Multiply()([input_feature, attention])


def spatial_attention(input_feature, kernel_size=7):
    """Spatial attention module"""
    if K.image_data_format() == "channels_first":
        cbam_feature = Permute((2, 3, 4, 1))(input_feature)
    else:
        cbam_feature = input_feature
    
    # Calculate channel averages and maxima
    avg_pool = Lambda(lambda x: tf.reduce_mean(x, axis=-1, keepdims=True))(cbam_feature)
    max_pool = Lambda(lambda x: tf.reduce_max(x, axis=-1, keepdims=True))(cbam_feature)
    
    # Feature fusion and convolution
    concat = Concatenate(axis=-1)([avg_pool, max_pool])
    attention = Conv3D(filters=1, kernel_size=kernel_size, strides=1, padding='same',
                       activation='sigmoid', kernel_initializer='he_normal', use_bias=False)(concat)
    
    if K.image_data_format() == "channels_first":
        attention = Permute((4, 1, 2, 3))(attention)
    
    return Multiply()([input_feature, attention])


def cbam_block(input_feature, ratio=8):
    """CBAM attention mechanism module"""
    x = channel_attention(input_feature, ratio)
    x = spatial_attention(x)
    return x


def conv_bn_relu(filters, kernel_size, strides, input_layer, dilation_rate=1):
    """3D Convolution + Batch Normalization + ReLU activation combination layer"""
    x = Conv3D(filters, kernel_size, strides=strides, padding='same', 
               dilation_rate=dilation_rate, kernel_initializer='he_normal')(input_layer)
    x = BatchNormalization()(x)
    return Activation('relu')(x)


def mcdc_block(filters, input_layer):
    """Multi-scale空洞卷积融合模块(MCDC) - Multi-scale空洞 convolution fusion module"""
    # Branch 1
    branch1 = conv_bn_relu(filters, (3, 3, 3), 1, input_layer, dilation_rate=1)
    branch1 = conv_bn_relu(filters, (1, 1, 1), 1, branch1)
    
    # Branch 2: 1->2->3
    branch2 = conv_bn_relu(filters, (3, 3, 3), 1, branch1, dilation_rate=2)
    branch2 = conv_bn_relu(filters, (3, 3, 3), 1, branch2, dilation_rate=3)
    branch2 = conv_bn_relu(filters, (1, 1, 1), 1, branch2)
    
    # Branch 3: 1->2->5
    branch3 = conv_bn_relu(filters, (3, 3, 3), 1, branch1, dilation_rate=2)
    branch3 = conv_bn_relu(filters, (3, 3, 3), 1, branch3, dilation_rate=5)
    branch3 = conv_bn_relu(filters, (1, 1, 1), 1, branch3)
    
    # Feature fusion
    fused = Concatenate()([branch1, branch2, branch3])
    fused = conv_bn_relu(filters * 2, (1, 1, 1), 2, fused)
    return conv_bn_relu(filters * 2, (1, 1, 1), 2, fused)


def residual_block(input_x, filters, downsample=False):
    """Residual block with optional downsampling"""
    # Main path
    x = conv_bn_relu(filters, (1, 1, 1), 2 if downsample else 1, input_x)
    x = conv_bn_relu(filters, (3, 3, 3), 1, x)
    x = conv_bn_relu(filters * 4, (1, 1, 1), 1, x)
    
    # Skip connection path
    if downsample:
        input_x = conv_bn_relu(filters * 4, (1, 1, 1), 2, input_x)
    
    return Add()([x, input_x])


def build_3d_resnet50_mcdc_cbam(input_shape=(23, 23, 63, 1), num_classes=17):
    """Build 3D ResNet50 combined with MCDC and CBAM model"""
    input_layer = Input(shape=input_shape, name='input_layer')
    
    # Initial convolution and pooling
    x = conv_bn_relu(64, (7, 7, 7), 1, input_layer)
    x = MaxPooling3D((3, 3, 3), strides=2, padding='same', name='initial_maxpool')(x)
    
    # Residual stages
    stage_outputs = []
    filters = 64
    num_residuals = [3, 4, 6, 3]
    
    for i, num_res in enumerate(num_residuals):
        for j in range(num_res):
            x = residual_block(x, filters, downsample=(j == 0))
        stage_outputs.append(x)
        filters *= 2
    
    # Extract stage outputs
    stage1, stage2, stage3, stage4 = stage_outputs
    
    # Shallow feature processing
    bottleneck1 = mcdc_block(64, stage1)
    bottleneck2 = mcdc_block(128, stage2)
    
    # Shallow feature fusion
    bottleneck1 = conv_bn_relu(256, (1, 1, 1), 1, bottleneck1)
    bottleneck2_up = UpSampling3D(size=(2, 2, 2))(bottleneck2)
    shallow_feature = Multiply()([bottleneck1, bottleneck2_up])
    
    # Deep feature processing
    bottleneck3 = mcdc_block(128, stage3)
    bottleneck2_resample = conv_bn_relu(256, (1, 1, 1), 1, bottleneck2)
    bottleneck3_fused = Multiply()([bottleneck2_resample, bottleneck3])
    bottleneck3_at = cbam_block(bottleneck3_fused)
    
    bottleneck4 = mcdc_block(256, stage4)
    bottleneck3_resample = conv_bn_relu(512, (1, 1, 1), 1, bottleneck3)
    bottleneck4_fused = Multiply()([bottleneck3_resample, bottleneck4])
    bottleneck4_at = cbam_block(bottleneck4_fused)
    
    # Deep feature fusion
    bottleneck3_at_resample = conv_bn_relu(512, (1, 1, 1), 1, bottleneck3_at)
    deep_feature = Multiply()([bottleneck3_at_resample, bottleneck4_at])
    
    # Feature matching and final fusion
    shallow_feature = conv_bn_relu(512, (1, 1, 1), 2, shallow_feature)
    stage4_output = conv_bn_relu(512, (1, 1, 1), 1, stage4)
    
    final_fused = Concatenate()([stage4_output, shallow_feature, deep_feature])
    final_fused = conv_bn_relu(256, (1, 1, 1), 1, final_fused)
    
    # Classification head
    x = GlobalAveragePooling3D()(final_fused)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.4)(x)
    output_layer = Dense(num_classes, activation='softmax', name='output_layer')(x)
    
    # Build model
    model = Model(inputs=[input_layer], outputs=[output_layer])
    return model

# %%
# Load and preprocess data
data_path = os.path.join(os.getcwd(), 'data')
HSI_PU = sio.loadmat(os.path.join(data_path, 'PaviaU.mat'))['paviaU']
print(f"Original HSI shape: {HSI_PU.shape}")
HSI_PU = np.transpose(HSI_PU, (1, 0, 2))
GT_PU = sio.loadmat(os.path.join(data_path, 'PaviaU_gt.mat'))['paviaU_gt']
GT_PU = np.transpose(GT_PU, (1, 0))
print(f"After transpose - HSI: {HSI_PU.shape}, GT: {GT_PU.shape}")
    
# Apply dimensionality reduction
HSI_PU = DL_Method(HSI_PU, numComponents=75)
    
# Extract cubes
HSI_PU_cube, GT_PU_cube = HSICubes(HSI_PU, GT_PU, WinSize=13)
print(f"Extracted cubes - HSI: {HSI_PU_cube.shape}, GT: {GT_PU_cube.shape}")

# %%
# Alternatively load pre-saved data
save_dir = os.path.join(os.getcwd(), 'data')
HSI_cube = np.load(os.path.join(save_dir, 'HSI_cube.npy'))
GT_cube = np.load(os.path.join(save_dir, 'GT_cube.npy'))

print("数据加载完成")
print(HSI_cube.shape, GT_cube.shape)
# Out:
# 数据加载完成
# (37298, 23, 23, 63) (37298,)

# %%
# Split into training, validation, and test sets
Tr, Te, TrC, TeC = SplitTr_Te(HSI_cube, GT_cube, 0.8)
Te, Tv, TeC, TvC = SplitTr_Te(Te, TeC, 0.75)
print(f"Dataset splits - Train: {Tr.shape}, Test: {Te.shape}, Validation: {Tv.shape}")
    
# Reshape data for 3D CNN and one-hot encode labels
Tr = Tr.reshape(-1, 23, 23, 63, 1)
TrC = to_categorical(TrC)
Te = Te.reshape(-1, 23, 23, 63, 1) 
TeC = to_categorical(TeC)
Tv = Tv.reshape(-1, 23, 23, 63, 1) 
TvC = to_categorical(TvC)
print(f"After reshaping - Train: {Tr.shape}, Train labels: {TrC.shape}")
print(f"Test: {Te.shape}, Test labels: {TeC.shape}")
print(f"Validation: {Tv.shape}, Validation labels: {TvC.shape}")
# Out:
# Dataset splits - Train: (7459, 23, 23, 63), Test: (7459, 23, 23, 63), Validation: (22380, 23, 23, 63)
# After reshaping - Train: (7459, 23, 23, 63, 1), Train labels: (7459, 17)
# Test: (7459, 23, 23, 63, 1), Test labels: (7459, 17)
# Validation: (22380, 23, 23, 63, 1), Validation labels: (22380, 17)

# %%
# Balance training dataset
Tr_balanced, TrC_balanced = balance_dataset(Tr, TrC, target=1500)
    
# Verify class distribution
class_counts = np.sum(TrC_balanced, axis=0)
print("Class distribution after balancing:")
for i in range(17):
    print(f"Class {i}: {int(class_counts[i])} samples")
# Out:
# Original class distribution: [ 685  859 1030  189  544    8  777   83  635   26   14  709  155   83
#   155  802  705]
# Augmenting class 0: from 685 to 1500
# Augmenting class 1: from 859 to 1500
# Augmenting class 2: from 1030 to 1500
# Augmenting class 3: from 189 to 1500
# Augmenting class 4: from 544 to 1500
# Augmenting class 5: from 8 to 1500
# Augmenting class 6: from 777 to 1500
# Augmenting class 7: from 83 to 1500
# Augmenting class 8: from 635 to 1500
# Augmenting class 9: from 26 to 1500
# Augmenting class 10: from 14 to 1500
# Augmenting class 11: from 709 to 1500
# Augmenting class 12: from 155 to 1500
# Augmenting class 13: from 83 to 1500
# Augmenting class 14: from 155 to 1500
# Augmenting class 15: from 802 to 1500
# Augmenting class 16: from 705 to 1500
# Balanced class distribution: [1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500 1500
#  1500 1500 1500]
# Class distribution after balancing:
# Class 0: 1500 samples
# Class 1: 1500 samples
# Class 2: 1500 samples
# Class 3: 1500 samples
# Class 4: 1500 samples
# Class 5: 1500 samples
# Class 6: 1500 samples
# Class 7: 1500 samples
# Class 8: 1500 samples
# Class 9: 1500 samples
# Class 10: 1500 samples
# Class 11: 1500 samples
# Class 12: 1500 samples
# Class 13: 1500 samples
# Class 14: 1500 samples
# Class 15: 1500 samples
# Class 16: 1500 samples

# %%
# Clean up memory
gc.collect()
    
# Build model
model = build_3d_resnet50_mcdc_cbam(
    input_shape=(23, 23, 63, 1),
    num_classes=17
)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_layer (InputLayer)       [(None, 23, 23, 63,  0           []
#                                  1)]
#
#  conv3d_204 (Conv3D)            (None, 23, 23, 63,   22016       ['input_layer[0][0]']
#                                 64)
#
#  batch_normalization_200 (Batch  (None, 23, 23, 63,   256        ['conv3d_204[0][0]']
#  Normalization)                 64)
#
#  activation_204 (Activation)    (None, 23, 23, 63,   0           ['batch_normalization_200[0][0]']
#                                 64)
#
#  initial_maxpool (MaxPooling3D)  (None, 12, 12, 32,   0          ['activation_204[0][0]']
#                                 64)
#
#  conv3d_205 (Conv3D)            (None, 6, 6, 16, 64  4160        ['initial_maxpool[0][0]']
#                                 )
#
#  batch_normalization_201 (Batch  (None, 6, 6, 16, 64  256        ['conv3d_205[0][0]']
#  Normalization)                 )
#
#  activation_205 (Activation)    (None, 6, 6, 16, 64  0           ['batch_normalization_201[0][0]']
#                                 )
#
#  conv3d_206 (Conv3D)            (None, 6, 6, 16, 64  110656      ['activation_205[0][0]']
#                                 )
#
#  batch_normalization_202 (Batch  (None, 6, 6, 16, 64  256        ['conv3d_206[0][0]']
#  Normalization)                 )
#
#  activation_206 (Activation)    (None, 6, 6, 16, 64  0           ['batch_normalization_202[0][0]']
#                                 )
#
#  conv3d_207 (Conv3D)            (None, 6, 6, 16, 25  16640       ['activation_206[0][0]']
#                                 6)
#
#  conv3d_208 (Conv3D)            (None, 6, 6, 16, 25  16640       ['initial_maxpool[0][0]']
#                                 6)
#
#  batch_normalization_203 (Batch  (None, 6, 6, 16, 25  1024       ['conv3d_207[0][0]']
#  Normalization)                 6)
#
#  batch_normalization_204 (Batch  (None, 6, 6, 16, 25  1024       ['conv3d_208[0][0]']
#  Normalization)                 6)
#
#  activation_207 (Activation)    (None, 6, 6, 16, 25  0           ['batch_normalization_203[0][0]']
#                                 6)
#
#  activation_208 (Activation)    (None, 6, 6, 16, 25  0           ['batch_normalization_204[0][0]']
#                                 6)
#
#  add_36 (Add)                   (None, 6, 6, 16, 25  0           ['activation_207[0][0]',
#                                 6)                                'activation_208[0][0]']
#
#  conv3d_209 (Conv3D)            (None, 6, 6, 16, 64  16448       ['add_36[0][0]']
#                                 )
#
#  batch_normalization_205 (Batch  (None, 6, 6, 16, 64  256        ['conv3d_209[0][0]']
#  Normalization)                 )
#
#  activation_209 (Activation)    (None, 6, 6, 16, 64  0           ['batch_normalization_205[0][0]']
#                                 )
#
#  conv3d_210 (Conv3D)            (None, 6, 6, 16, 64  110656      ['activation_209[0][0]']
#                                 )
#
#  batch_normalization_206 (Batch  (None, 6, 6, 16, 64  256        ['conv3d_210[0][0]']
#  Normalization)                 )
#
#  activation_210 (Activation)    (None, 6, 6, 16, 64  0           ['batch_normalization_206[0][0]']
#                                 )
#
#  conv3d_211 (Conv3D)            (None, 6, 6, 16, 25  16640       ['activation_210[0][0]']
#                                 6)
#
#  batch_normalization_207 (Batch  (None, 6, 6, 16, 25  1024       ['conv3d_211[0][0]']
#  Normalization)                 6)
#
#  activation_211 (Activation)    (None, 6, 6, 16, 25  0           ['batch_normalization_207[0][0]']
#                                 6)
#
#  add_37 (Add)                   (None, 6, 6, 16, 25  0           ['activation_211[0][0]',
#                                 6)                                'add_36[0][0]']
#
#  conv3d_212 (Conv3D)            (None, 6, 6, 16, 64  16448       ['add_37[0][0]']
#                                 )
#
#  batch_normalization_208 (Batch  (None, 6, 6, 16, 64  256        ['conv3d_212[0][0]']
#  Normalization)                 )
#
#  activation_212 (Activation)    (None, 6, 6, 16, 64  0           ['batch_normalization_208[0][0]']
#                                 )
#
#  conv3d_213 (Conv3D)            (None, 6, 6, 16, 64  110656      ['activation_212[0][0]']
#                                 )
#
#  batch_normalization_209 (Batch  (None, 6, 6, 16, 64  256        ['conv3d_213[0][0]']
#  Normalization)                 )
#
#  activation_213 (Activation)    (None, 6, 6, 16, 64  0           ['batch_normalization_209[0][0]']
#                                 )
#
#  conv3d_214 (Conv3D)            (None, 6, 6, 16, 25  16640       ['activation_213[0][0]']
#                                 6)
#
#  batch_normalization_210 (Batch  (None, 6, 6, 16, 25  1024       ['conv3d_214[0][0]']
#  Normalization)                 6)
#
#  activation_214 (Activation)    (None, 6, 6, 16, 25  0           ['batch_normalization_210[0][0]']
#                                 6)
#
#  add_38 (Add)                   (None, 6, 6, 16, 25  0           ['activation_214[0][0]',
#                                 6)                                'add_37[0][0]']
#
#  conv3d_215 (Conv3D)            (None, 3, 3, 8, 128  32896       ['add_38[0][0]']
#                                 )
#
#  batch_normalization_211 (Batch  (None, 3, 3, 8, 128  512        ['conv3d_215[0][0]']
#  Normalization)                 )
#
#  activation_215 (Activation)    (None, 3, 3, 8, 128  0           ['batch_normalization_211[0][0]']
#                                 )
#
#  conv3d_216 (Conv3D)            (None, 3, 3, 8, 128  442496      ['activation_215[0][0]']
#                                 )
#
#  batch_normalization_212 (Batch  (None, 3, 3, 8, 128  512        ['conv3d_216[0][0]']
#  Normalization)                 )
#
#  activation_216 (Activation)    (None, 3, 3, 8, 128  0           ['batch_normalization_212[0][0]']
#                                 )
#
#  conv3d_217 (Conv3D)            (None, 3, 3, 8, 512  66048       ['activation_216[0][0]']
#                                 )
#
#  conv3d_218 (Conv3D)            (None, 3, 3, 8, 512  131584      ['add_38[0][0]']
#                                 )
#
#  batch_normalization_213 (Batch  (None, 3, 3, 8, 512  2048       ['conv3d_217[0][0]']
#  Normalization)                 )
#
#  batch_normalization_214 (Batch  (None, 3, 3, 8, 512  2048       ['conv3d_218[0][0]']
#  Normalization)                 )
#
#  activation_217 (Activation)    (None, 3, 3, 8, 512  0           ['batch_normalization_213[0][0]']
#                                 )
#
#  activation_218 (Activation)    (None, 3, 3, 8, 512  0           ['batch_normalization_214[0][0]']
#                                 )
#
#  add_39 (Add)                   (None, 3, 3, 8, 512  0           ['activation_217[0][0]',
#                                 )                                 'activation_218[0][0]']
#
#  conv3d_219 (Conv3D)            (None, 3, 3, 8, 128  65664       ['add_39[0][0]']
#                                 )
#
#  batch_normalization_215 (Batch  (None, 3, 3, 8, 128  512        ['conv3d_219[0][0]']
#  Normalization)                 )
#
#  activation_219 (Activation)    (None, 3, 3, 8, 128  0           ['batch_normalization_215[0][0]']
#                                 )
#
#  conv3d_220 (Conv3D)            (None, 3, 3, 8, 128  442496      ['activation_219[0][0]']
#                                 )
#
#  batch_normalization_216 (Batch  (None, 3, 3, 8, 128  512        ['conv3d_220[0][0]']
#  Normalization)                 )
#
#  activation_220 (Activation)    (None, 3, 3, 8, 128  0           ['batch_normalization_216[0][0]']
#                                 )
#
#  conv3d_221 (Conv3D)            (None, 3, 3, 8, 512  66048       ['activation_220[0][0]']
#                                 )
#
#  batch_normalization_217 (Batch  (None, 3, 3, 8, 512  2048       ['conv3d_221[0][0]']
#  Normalization)                 )
#
#  activation_221 (Activation)    (None, 3, 3, 8, 512  0           ['batch_normalization_217[0][0]']
#                                 )
#
#  add_40 (Add)                   (None, 3, 3, 8, 512  0           ['activation_221[0][0]',
#                                 )                                 'add_39[0][0]']
#
#  conv3d_222 (Conv3D)            (None, 3, 3, 8, 128  65664       ['add_40[0][0]']
#                                 )
#
#  batch_normalization_218 (Batch  (None, 3, 3, 8, 128  512        ['conv3d_222[0][0]']
#  Normalization)                 )
#
#  activation_222 (Activation)    (None, 3, 3, 8, 128  0           ['batch_normalization_218[0][0]']
#                                 )
#
#  conv3d_223 (Conv3D)            (None, 3, 3, 8, 128  442496      ['activation_222[0][0]']
#                                 )
#
#  batch_normalization_219 (Batch  (None, 3, 3, 8, 128  512        ['conv3d_223[0][0]']
#  Normalization)                 )
#
#  activation_223 (Activation)    (None, 3, 3, 8, 128  0           ['batch_normalization_219[0][0]']
#                                 )
#
#  conv3d_224 (Conv3D)            (None, 3, 3, 8, 512  66048       ['activation_223[0][0]']
#                                 )
#
#  batch_normalization_220 (Batch  (None, 3, 3, 8, 512  2048       ['conv3d_224[0][0]']
#  Normalization)                 )
#
#  activation_224 (Activation)    (None, 3, 3, 8, 512  0           ['batch_normalization_220[0][0]']
#                                 )
#
#  add_41 (Add)                   (None, 3, 3, 8, 512  0           ['activation_224[0][0]',
#                                 )                                 'add_40[0][0]']
#
#  conv3d_225 (Conv3D)            (None, 3, 3, 8, 128  65664       ['add_41[0][0]']
#                                 )
#
#  batch_normalization_221 (Batch  (None, 3, 3, 8, 128  512        ['conv3d_225[0][0]']
#  Normalization)                 )
#
#  activation_225 (Activation)    (None, 3, 3, 8, 128  0           ['batch_normalization_221[0][0]']
#                                 )
#
#  conv3d_226 (Conv3D)            (None, 3, 3, 8, 128  442496      ['activation_225[0][0]']
#                                 )
#
#  batch_normalization_222 (Batch  (None, 3, 3, 8, 128  512        ['conv3d_226[0][0]']
#  Normalization)                 )
#
#  activation_226 (Activation)    (None, 3, 3, 8, 128  0           ['batch_normalization_222[0][0]']
#                                 )
#
#  conv3d_227 (Conv3D)            (None, 3, 3, 8, 512  66048       ['activation_226[0][0]']
#                                 )
#
#  batch_normalization_223 (Batch  (None, 3, 3, 8, 512  2048       ['conv3d_227[0][0]']
#  Normalization)                 )
#
#  activation_227 (Activation)    (None, 3, 3, 8, 512  0           ['batch_normalization_223[0][0]']
#                                 )
#
#  add_42 (Add)                   (None, 3, 3, 8, 512  0           ['activation_227[0][0]',
#                                 )                                 'add_41[0][0]']
#
#  conv3d_228 (Conv3D)            (None, 2, 2, 4, 256  131328      ['add_42[0][0]']
#                                 )
#
#  batch_normalization_224 (Batch  (None, 2, 2, 4, 256  1024       ['conv3d_228[0][0]']
#  Normalization)                 )
#
#  activation_228 (Activation)    (None, 2, 2, 4, 256  0           ['batch_normalization_224[0][0]']
#                                 )
#
#  conv3d_229 (Conv3D)            (None, 2, 2, 4, 256  1769728     ['activation_228[0][0]']
#                                 )
#
#  batch_normalization_225 (Batch  (None, 2, 2, 4, 256  1024       ['conv3d_229[0][0]']
#  Normalization)                 )
#
#  activation_229 (Activation)    (None, 2, 2, 4, 256  0           ['batch_normalization_225[0][0]']
#                                 )
#
#  conv3d_230 (Conv3D)            (None, 2, 2, 4, 102  263168      ['activation_229[0][0]']
#                                 4)
#
#  conv3d_231 (Conv3D)            (None, 2, 2, 4, 102  525312      ['add_42[0][0]']
#                                 4)
#
#  batch_normalization_226 (Batch  (None, 2, 2, 4, 102  4096       ['conv3d_230[0][0]']
#  Normalization)                 4)
#
#  batch_normalization_227 (Batch  (None, 2, 2, 4, 102  4096       ['conv3d_231[0][0]']
#  Normalization)                 4)
#
#  activation_230 (Activation)    (None, 2, 2, 4, 102  0           ['batch_normalization_226[0][0]']
#                                 4)
#
#  activation_231 (Activation)    (None, 2, 2, 4, 102  0           ['batch_normalization_227[0][0]']
#                                 4)
#
#  add_43 (Add)                   (None, 2, 2, 4, 102  0           ['activation_230[0][0]',
#                                 4)                                'activation_231[0][0]']
#
#  conv3d_232 (Conv3D)            (None, 2, 2, 4, 256  262400      ['add_43[0][0]']
#                                 )
#
#  batch_normalization_228 (Batch  (None, 2, 2, 4, 256  1024       ['conv3d_232[0][0]']
#  Normalization)                 )
#
#  activation_232 (Activation)    (None, 2, 2, 4, 256  0           ['batch_normalization_228[0][0]']
#                                 )
#
#  conv3d_233 (Conv3D)            (None, 2, 2, 4, 256  1769728     ['activation_232[0][0]']
#                                 )
#
#  batch_normalization_229 (Batch  (None, 2, 2, 4, 256  1024       ['conv3d_233[0][0]']
#  Normalization)                 )
#
#  activation_233 (Activation)    (None, 2, 2, 4, 256  0           ['batch_normalization_229[0][0]']
#                                 )
#
#  conv3d_234 (Conv3D)            (None, 2, 2, 4, 102  263168      ['activation_233[0][0]']
#                                 4)
#
#  batch_normalization_230 (Batch  (None, 2, 2, 4, 102  4096       ['conv3d_234[0][0]']
#  Normalization)                 4)
#
#  activation_234 (Activation)    (None, 2, 2, 4, 102  0           ['batch_normalization_230[0][0]']
#                                 4)
#
#  add_44 (Add)                   (None, 2, 2, 4, 102  0           ['activation_234[0][0]',
#                                 4)                                'add_43[0][0]']
#
#  conv3d_235 (Conv3D)            (None, 2, 2, 4, 256  262400      ['add_44[0][0]']
#                                 )
#
#  batch_normalization_231 (Batch  (None, 2, 2, 4, 256  1024       ['conv3d_235[0][0]']
#  Normalization)                 )
#
#  activation_235 (Activation)    (None, 2, 2, 4, 256  0           ['batch_normalization_231[0][0]']
#                                 )
#
#  conv3d_236 (Conv3D)            (None, 2, 2, 4, 256  1769728     ['activation_235[0][0]']
#                                 )
#
#  batch_normalization_232 (Batch  (None, 2, 2, 4, 256  1024       ['conv3d_236[0][0]']
#  Normalization)                 )
#
#  activation_236 (Activation)    (None, 2, 2, 4, 256  0           ['batch_normalization_232[0][0]']
#                                 )
#
#  conv3d_237 (Conv3D)            (None, 2, 2, 4, 102  263168      ['activation_236[0][0]']
#                                 4)
#
#  batch_normalization_233 (Batch  (None, 2, 2, 4, 102  4096       ['conv3d_237[0][0]']
#  Normalization)                 4)
#
#  activation_237 (Activation)    (None, 2, 2, 4, 102  0           ['batch_normalization_233[0][0]']
#                                 4)
#
#  add_45 (Add)                   (None, 2, 2, 4, 102  0           ['activation_237[0][0]',
#                                 4)                                'add_44[0][0]']
#
#  conv3d_238 (Conv3D)            (None, 2, 2, 4, 256  262400      ['add_45[0][0]']
#                                 )
#
#  batch_normalization_234 (Batch  (None, 2, 2, 4, 256  1024       ['conv3d_238[0][0]']
#  Normalization)                 )
#
#  activation_238 (Activation)    (None, 2, 2, 4, 256  0           ['batch_normalization_234[0][0]']
#                                 )
#
#  conv3d_239 (Conv3D)            (None, 2, 2, 4, 256  1769728     ['activation_238[0][0]']
#                                 )
#
#  batch_normalization_235 (Batch  (None, 2, 2, 4, 256  1024       ['conv3d_239[0][0]']
#  Normalization)                 )
#
#  activation_239 (Activation)    (None, 2, 2, 4, 256  0           ['batch_normalization_235[0][0]']
#                                 )
#
#  conv3d_240 (Conv3D)            (None, 2, 2, 4, 102  263168      ['activation_239[0][0]']
#                                 4)
#
#  batch_normalization_236 (Batch  (None, 2, 2, 4, 102  4096       ['conv3d_240[0][0]']
#  Normalization)                 4)
#
#  activation_240 (Activation)    (None, 2, 2, 4, 102  0           ['batch_normalization_236[0][0]']
#                                 4)
#
#  add_46 (Add)                   (None, 2, 2, 4, 102  0           ['activation_240[0][0]',
#                                 4)                                'add_45[0][0]']
#
#  conv3d_241 (Conv3D)            (None, 2, 2, 4, 256  262400      ['add_46[0][0]']
#                                 )
#
#  batch_normalization_237 (Batch  (None, 2, 2, 4, 256  1024       ['conv3d_241[0][0]']
#  Normalization)                 )
#
#  activation_241 (Activation)    (None, 2, 2, 4, 256  0           ['batch_normalization_237[0][0]']
#                                 )
#
#  conv3d_242 (Conv3D)            (None, 2, 2, 4, 256  1769728     ['activation_241[0][0]']
#                                 )
#
#  batch_normalization_238 (Batch  (None, 2, 2, 4, 256  1024       ['conv3d_242[0][0]']
#  Normalization)                 )
#
#  activation_242 (Activation)    (None, 2, 2, 4, 256  0           ['batch_normalization_238[0][0]']
#                                 )
#
#  conv3d_243 (Conv3D)            (None, 2, 2, 4, 102  263168      ['activation_242[0][0]']
#                                 4)
#
#  batch_normalization_239 (Batch  (None, 2, 2, 4, 102  4096       ['conv3d_243[0][0]']
#  Normalization)                 4)
#
#  activation_243 (Activation)    (None, 2, 2, 4, 102  0           ['batch_normalization_239[0][0]']
#                                 4)
#
#  add_47 (Add)                   (None, 2, 2, 4, 102  0           ['activation_243[0][0]',
#                                 4)                                'add_46[0][0]']
#
#  conv3d_244 (Conv3D)            (None, 2, 2, 4, 256  262400      ['add_47[0][0]']
#                                 )
#
#  batch_normalization_240 (Batch  (None, 2, 2, 4, 256  1024       ['conv3d_244[0][0]']
#  Normalization)                 )
#
#  activation_244 (Activation)    (None, 2, 2, 4, 256  0           ['batch_normalization_240[0][0]']
#                                 )
#
#  conv3d_245 (Conv3D)            (None, 2, 2, 4, 256  1769728     ['activation_244[0][0]']
#                                 )
#
#  batch_normalization_241 (Batch  (None, 2, 2, 4, 256  1024       ['conv3d_245[0][0]']
#  Normalization)                 )
#
#  activation_245 (Activation)    (None, 2, 2, 4, 256  0           ['batch_normalization_241[0][0]']
#                                 )
#
#  conv3d_246 (Conv3D)            (None, 2, 2, 4, 102  263168      ['activation_245[0][0]']
#                                 4)
#
#  batch_normalization_242 (Batch  (None, 2, 2, 4, 102  4096       ['conv3d_246[0][0]']
#  Normalization)                 4)
#
#  activation_246 (Activation)    (None, 2, 2, 4, 102  0           ['batch_normalization_242[0][0]']
#                                 4)
#
#  add_48 (Add)                   (None, 2, 2, 4, 102  0           ['activation_246[0][0]',
#                                 4)                                'add_47[0][0]']
#
#  conv3d_247 (Conv3D)            (None, 1, 1, 2, 512  524800      ['add_48[0][0]']
#                                 )
#
#  batch_normalization_243 (Batch  (None, 1, 1, 2, 512  2048       ['conv3d_247[0][0]']
#  Normalization)                 )
#
#  activation_247 (Activation)    (None, 1, 1, 2, 512  0           ['batch_normalization_243[0][0]']
#                                 )
#
#  conv3d_248 (Conv3D)            (None, 1, 1, 2, 512  7078400     ['activation_247[0][0]']
#                                 )
#
#  batch_normalization_244 (Batch  (None, 1, 1, 2, 512  2048       ['conv3d_248[0][0]']
#  Normalization)                 )
#
#  activation_248 (Activation)    (None, 1, 1, 2, 512  0           ['batch_normalization_244[0][0]']
#                                 )
#
#  conv3d_249 (Conv3D)            (None, 1, 1, 2, 204  1050624     ['activation_248[0][0]']
#                                 8)
#
#  conv3d_250 (Conv3D)            (None, 1, 1, 2, 204  2099200     ['add_48[0][0]']
#                                 8)
#
#  batch_normalization_245 (Batch  (None, 1, 1, 2, 204  8192       ['conv3d_249[0][0]']
#  Normalization)                 8)
#
#  batch_normalization_246 (Batch  (None, 1, 1, 2, 204  8192       ['conv3d_250[0][0]']
#  Normalization)                 8)
#
#  activation_249 (Activation)    (None, 1, 1, 2, 204  0           ['batch_normalization_245[0][0]']
#                                 8)
#
#  activation_250 (Activation)    (None, 1, 1, 2, 204  0           ['batch_normalization_246[0][0]']
#                                 8)
#
#  add_49 (Add)                   (None, 1, 1, 2, 204  0           ['activation_249[0][0]',
#                                 8)                                'activation_250[0][0]']
#
#  conv3d_251 (Conv3D)            (None, 1, 1, 2, 512  1049088     ['add_49[0][0]']
#                                 )
#
#  batch_normalization_247 (Batch  (None, 1, 1, 2, 512  2048       ['conv3d_251[0][0]']
#  Normalization)                 )
#
#  activation_251 (Activation)    (None, 1, 1, 2, 512  0           ['batch_normalization_247[0][0]']
#                                 )
#
#  conv3d_252 (Conv3D)            (None, 1, 1, 2, 512  7078400     ['activation_251[0][0]']
# ...
#  conv3d_265 (Conv3D)            (None, 3, 3, 8, 128  24704       ['concatenate_14[0][0]']
#                                 )
#
#  dense_18 (Dense)               (None, 1, 1, 32)     8224        ['reshape_8[0][0]']
#
#  dense_20 (Dense)               (None, 1, 1, 32)     8224        ['reshape_9[0][0]']
#
#  multiply_20 (Multiply)         (None, 1, 1, 1, 512  0           ['activation_300[0][0]',
#                                 )                                 'activation_299[0][0]']
#
#  batch_normalization_261 (Batch  (None, 3, 3, 8, 128  512        ['conv3d_265[0][0]']
#  Normalization)                 )
#
#  dense_19 (Dense)               (None, 1, 1, 256)    8448        ['dense_18[0][0]']
#
#  dense_21 (Dense)               (None, 1, 1, 256)    8448        ['dense_20[0][0]']
#
#  global_average_pooling3d_7 (Gl  (None, 512)         0           ['multiply_20[0][0]']
#  obalAveragePooling3D)
#
#  global_max_pooling3d_5 (Global  (None, 512)         0           ['multiply_20[0][0]']
#  MaxPooling3D)
#
#  activation_265 (Activation)    (None, 3, 3, 8, 128  0           ['batch_normalization_261[0][0]']
#                                 )
#
#  add_52 (Add)                   (None, 1, 1, 256)    0           ['dense_19[0][0]',
#                                                                   'dense_21[0][0]']
#
#  reshape_10 (Reshape)           (None, 1, 1, 512)    0           ['global_average_pooling3d_7[0][0
#                                                                  ]']
#
#  reshape_11 (Reshape)           (None, 1, 1, 512)    0           ['global_max_pooling3d_5[0][0]']
#
#  conv3d_266 (Conv3D)            (None, 2, 2, 4, 128  16512       ['activation_265[0][0]']
#                                 )
#
#  activation_289 (Activation)    (None, 1, 1, 256)    0           ['add_52[0][0]']
#
#  dense_22 (Dense)               (None, 1, 1, 64)     32832       ['reshape_10[0][0]']
#
#  dense_24 (Dense)               (None, 1, 1, 64)     32832       ['reshape_11[0][0]']
#
#  batch_normalization_262 (Batch  (None, 2, 2, 4, 128  512        ['conv3d_266[0][0]']
#  Normalization)                 )
#
#  multiply_18 (Multiply)         (None, 1, 1, 2, 256  0           ['multiply_17[0][0]',
#                                 )                                 'activation_289[0][0]']
#
#  dense_23 (Dense)               (None, 1, 1, 512)    33280       ['dense_22[0][0]']
#
#  dense_25 (Dense)               (None, 1, 1, 512)    33280       ['dense_24[0][0]']
#
#  activation_266 (Activation)    (None, 2, 2, 4, 128  0           ['batch_normalization_262[0][0]']
#                                 )
#
#  lambda_8 (Lambda)              (None, 1, 1, 2, 1)   0           ['multiply_18[0][0]']
#
#  lambda_9 (Lambda)              (None, 1, 1, 2, 1)   0           ['multiply_18[0][0]']
#
#  add_53 (Add)                   (None, 1, 1, 512)    0           ['dense_23[0][0]',
#                                                                   'dense_25[0][0]']
#
#  conv3d_277 (Conv3D)            (None, 2, 2, 4, 256  33024       ['activation_266[0][0]']
#                                 )
#
#  concatenate_17 (Concatenate)   (None, 1, 1, 2, 2)   0           ['lambda_8[0][0]',
#                                                                   'lambda_9[0][0]']
#
#  activation_301 (Activation)    (None, 1, 1, 512)    0           ['add_53[0][0]']
#
#  batch_normalization_273 (Batch  (None, 2, 2, 4, 256  1024       ['conv3d_277[0][0]']
#  Normalization)                 )
#
#  conv3d_289 (Conv3D)            (None, 1, 1, 2, 1)   686         ['concatenate_17[0][0]']
#
#  multiply_21 (Multiply)         (None, 1, 1, 1, 512  0           ['multiply_20[0][0]',
#                                 )                                 'activation_301[0][0]']
#
#  activation_277 (Activation)    (None, 2, 2, 4, 256  0           ['batch_normalization_273[0][0]']
#                                 )
#
#  up_sampling3d_2 (UpSampling3D)  (None, 2, 2, 4, 256  0          ['activation_276[0][0]']
#                                 )
#
#  multiply_19 (Multiply)         (None, 1, 1, 2, 256  0           ['multiply_18[0][0]',
#                                 )                                 'conv3d_289[0][0]']
#
#  lambda_10 (Lambda)             (None, 1, 1, 1, 1)   0           ['multiply_21[0][0]']
#
#  lambda_11 (Lambda)             (None, 1, 1, 1, 1)   0           ['multiply_21[0][0]']
#
#  multiply_16 (Multiply)         (None, 2, 2, 4, 256  0           ['activation_277[0][0]',
#                                 )                                 'up_sampling3d_2[0][0]']
#
#  conv3d_302 (Conv3D)            (None, 1, 1, 2, 512  131584      ['multiply_19[0][0]']
#                                 )
#
#  concatenate_19 (Concatenate)   (None, 1, 1, 1, 2)   0           ['lambda_10[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  conv3d_304 (Conv3D)            (None, 1, 1, 2, 512  1049088     ['add_51[0][0]']
#                                 )
#
#  conv3d_303 (Conv3D)            (None, 1, 1, 2, 512  131584      ['multiply_16[0][0]']
#                                 )
#
#  batch_normalization_296 (Batch  (None, 1, 1, 2, 512  2048       ['conv3d_302[0][0]']
#  Normalization)                 )
#
#  conv3d_301 (Conv3D)            (None, 1, 1, 1, 1)   686         ['concatenate_19[0][0]']
#
#  batch_normalization_298 (Batch  (None, 1, 1, 2, 512  2048       ['conv3d_304[0][0]']
#  Normalization)                 )
#
#  batch_normalization_297 (Batch  (None, 1, 1, 2, 512  2048       ['conv3d_303[0][0]']
#  Normalization)                 )
#
#  activation_302 (Activation)    (None, 1, 1, 2, 512  0           ['batch_normalization_296[0][0]']
#                                 )
#
#  multiply_22 (Multiply)         (None, 1, 1, 1, 512  0           ['multiply_21[0][0]',
#                                 )                                 'conv3d_301[0][0]']
#
#  activation_304 (Activation)    (None, 1, 1, 2, 512  0           ['batch_normalization_298[0][0]']
#                                 )
#
#  activation_303 (Activation)    (None, 1, 1, 2, 512  0           ['batch_normalization_297[0][0]']
#                                 )
#
#  multiply_23 (Multiply)         (None, 1, 1, 2, 512  0           ['activation_302[0][0]',
#                                 )                                 'multiply_22[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 1, 1, 2, 153  0           ['activation_304[0][0]',
#                                 6)                                'activation_303[0][0]',
#                                                                   'multiply_23[0][0]']
#
#  conv3d_305 (Conv3D)            (None, 1, 1, 2, 256  393472      ['concatenate_20[0][0]']
#                                 )
#
#  batch_normalization_299 (Batch  (None, 1, 1, 2, 256  1024       ['conv3d_305[0][0]']
#  Normalization)                 )
#
#  activation_305 (Activation)    (None, 1, 1, 2, 256  0           ['batch_normalization_299[0][0]']
#                                 )
#
#  global_average_pooling3d_8 (Gl  (None, 256)         0           ['activation_305[0][0]']
#  obalAveragePooling3D)
#
#  flatten_2 (Flatten)            (None, 256)          0           ['global_average_pooling3d_8[0][0
#                                                                  ]']
#
#  dense_26 (Dense)               (None, 128)          32896       ['flatten_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 128)          0           ['dense_26[0][0]']
#
#  output_layer (Dense)           (None, 17)           2193        ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 80,715,693
# Trainable params: 80,643,117
# Non-trainable params: 72,576
# __________________________________________________________________________________________________

# %%
# Define callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-5
    )
]
    
# Compile model
optimizer = Adam(learning_rate=0.001, decay=1e-06)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
# Train model
start_time = time.time()
history = model.fit(
    x=Tr_balanced, 
    y=TrC_balanced, 
    batch_size=128, 
    epochs=100, 
    validation_data=(Te, TeC),
    callbacks=callbacks
)
training_time = time.time() - start_time
print(f"Training time: {training_time:.2f} seconds")
# Out:
# Epoch 1/100
# 200/200 [==============================] - 83s 361ms/step - loss: 1.8314 - accuracy: 0.4040 - val_loss: 1.6161 - val_accuracy: 0.4672 - lr: 0.0010
# Epoch 2/100
# 200/200 [==============================] - 66s 330ms/step - loss: 0.7479 - accuracy: 0.7612 - val_loss: 0.8130 - val_accuracy: 0.7378 - lr: 0.0010
# Epoch 3/100
# 200/200 [==============================] - 66s 332ms/step - loss: 0.4721 - accuracy: 0.8549 - val_loss: 0.3951 - val_accuracy: 0.8862 - lr: 0.0010
# Epoch 4/100
# 200/200 [==============================] - 66s 330ms/step - loss: 0.3566 - accuracy: 0.8896 - val_loss: 0.3277 - val_accuracy: 0.8914 - lr: 0.0010
# Epoch 5/100
# 200/200 [==============================] - 66s 329ms/step - loss: 0.2874 - accuracy: 0.9120 - val_loss: 0.2669 - val_accuracy: 0.9192 - lr: 0.0010
# Epoch 6/100
# 200/200 [==============================] - 66s 329ms/step - loss: 0.2132 - accuracy: 0.9342 - val_loss: 0.2031 - val_accuracy: 0.9406 - lr: 0.0010
# Epoch 7/100
# 200/200 [==============================] - 65s 327ms/step - loss: 0.1836 - accuracy: 0.9447 - val_loss: 0.2587 - val_accuracy: 0.9181 - lr: 0.0010
# Epoch 8/100
# 200/200 [==============================] - 66s 328ms/step - loss: 0.1475 - accuracy: 0.9556 - val_loss: 0.1871 - val_accuracy: 0.9483 - lr: 0.0010
# Epoch 9/100
# 200/200 [==============================] - 65s 325ms/step - loss: 0.1498 - accuracy: 0.9532 - val_loss: 0.2056 - val_accuracy: 0.9405 - lr: 0.0010
# Epoch 10/100
# 200/200 [==============================] - 65s 327ms/step - loss: 0.1163 - accuracy: 0.9642 - val_loss: 0.1406 - val_accuracy: 0.9623 - lr: 0.0010
# Epoch 11/100
# 200/200 [==============================] - 65s 323ms/step - loss: 0.1119 - accuracy: 0.9644 - val_loss: 0.1826 - val_accuracy: 0.9461 - lr: 0.0010
# Epoch 12/100
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0895 - accuracy: 0.9725 - val_loss: 0.1717 - val_accuracy: 0.9568 - lr: 0.0010
# Epoch 13/100
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0904 - accuracy: 0.9720 - val_loss: 0.1760 - val_accuracy: 0.9572 - lr: 0.0010
# Epoch 14/100
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0801 - accuracy: 0.9747 - val_loss: 0.2264 - val_accuracy: 0.9385 - lr: 0.0010
# Epoch 15/100
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0646 - accuracy: 0.9802 - val_loss: 0.2096 - val_accuracy: 0.9488 - lr: 0.0010
# Epoch 16/100
# 200/200 [==============================] - 65s 327ms/step - loss: 0.0287 - accuracy: 0.9915 - val_loss: 0.1184 - val_accuracy: 0.9737 - lr: 5.0000e-04
# Epoch 17/100
# 200/200 [==============================] - 65s 327ms/step - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.1177 - val_accuracy: 0.9749 - lr: 5.0000e-04
# Epoch 18/100
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0219 - accuracy: 0.9931 - val_loss: 0.1330 - val_accuracy: 0.9732 - lr: 5.0000e-04
# Epoch 19/100
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0203 - accuracy: 0.9936 - val_loss: 0.1260 - val_accuracy: 0.9751 - lr: 5.0000e-04
# Epoch 20/100
# 200/200 [==============================] - 64s 322ms/step - loss: 0.0146 - accuracy: 0.9961 - val_loss: 0.1576 - val_accuracy: 0.9717 - lr: 5.0000e-04
# Epoch 21/100
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0149 - accuracy: 0.9956 - val_loss: 0.1518 - val_accuracy: 0.9696 - lr: 5.0000e-04
# Epoch 22/100
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0250 - accuracy: 0.9926 - val_loss: 0.1606 - val_accuracy: 0.9688 - lr: 5.0000e-04
# Epoch 23/100
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0083 - accuracy: 0.9979 - val_loss: 0.1215 - val_accuracy: 0.9773 - lr: 2.5000e-04
# Epoch 24/100
# 200/200 [==============================] - 65s 323ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.1159 - val_accuracy: 0.9787 - lr: 2.5000e-04
# Epoch 25/100
# 200/200 [==============================] - 65s 326ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.1212 - val_accuracy: 0.9791 - lr: 2.5000e-04
# Epoch 26/100
# 200/200 [==============================] - 65s 323ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.1459 - val_accuracy: 0.9763 - lr: 2.5000e-04
# Epoch 27/100
# 200/200 [==============================] - 65s 323ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.1418 - val_accuracy: 0.9764 - lr: 2.5000e-04
# Epoch 28/100
# 200/200 [==============================] - 65s 325ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.1298 - val_accuracy: 0.9784 - lr: 2.5000e-04
# Epoch 29/100
# 200/200 [==============================] - 64s 323ms/step - loss: 0.0051 - accuracy: 0.9987 - val_loss: 0.1544 - val_accuracy: 0.9741 - lr: 2.5000e-04
# Epoch 30/100
# 200/200 [==============================] - 65s 324ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.1323 - val_accuracy: 0.9779 - lr: 1.2500e-04
# Epoch 31/100
# 200/200 [==============================] - 64s 322ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1381 - val_accuracy: 0.9783 - lr: 1.2500e-04
# Epoch 32/100
# 200/200 [==============================] - 65s 326ms/step - loss: 5.7745e-04 - accuracy: 0.9999 - val_loss: 0.1341 - val_accuracy: 0.9785 - lr: 1.2500e-04
# Epoch 33/100
# 200/200 [==============================] - 65s 323ms/step - loss: 8.2999e-04 - accuracy: 0.9999 - val_loss: 0.1384 - val_accuracy: 0.9781 - lr: 1.2500e-04
# Epoch 34/100
# 200/200 [==============================] - 65s 323ms/step - loss: 4.8318e-04 - accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 0.9781 - lr: 1.2500e-04
# Training time: 2238.67 seconds

# %%
# Evaluate model
predictions = model.predict(Tv)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(TvC, axis=1)
    
# Calculate and save confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
cm_df = pd.DataFrame(cm)
cm_df.to_csv(os.path.join(save_dir, 'model_confusion_T1500.csv'), index=False, header=True)
    
# Calculate and save precision matrix
precision_matrix = cm.astype('float') / cm.sum(axis=0, keepdims=True)
pm_df = pd.DataFrame(precision_matrix)
pm_df.to_csv(os.path.join(save_dir, 'model_precision_T1500.csv'), index=False, header=True)
    
# Calculate evaluation metrics
oa = accuracy_score(true_classes, predicted_classes)
print(f"Overall Accuracy (OA): {oa:.4f}")
    
aa = np.mean(np.diag(cm) / np.sum(cm, axis=1))
print(f"Average Accuracy (AA): {aa:.4f}")
    
recall = recall_score(true_classes, predicted_classes, average=None)
print("Class-wise Recall:")
for class_idx, r in enumerate(recall):
    print(f"Class {class_idx}: {r:.4f}")
    
f1 = f1_score(true_classes, predicted_classes, average=None)
print("Class-wise F1 Score:")
for class_idx, f in enumerate(f1):
    print(f"Class {class_idx}: {f:.4f}")
    
kappa = cohen_kappa_score(true_classes, predicted_classes)
print(f"Kappa Coefficient: {kappa:.4f}")
